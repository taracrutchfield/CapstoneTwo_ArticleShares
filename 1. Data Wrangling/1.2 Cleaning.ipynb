# %% [markdown]
# # Data Cleaning
# Adding Updates.csv to the main dataset and cleaning everything up so its ready for analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Original dataset
raw = pd.read_csv("../Data/Raw.csv").set_index('url')

# Results of my own search
update_data = pd.read_csv("../Data/Web Results.csv").set_index('url')

# %% [markdown]
# # Updates Dataframe
# Since this was data scrapped from the article html, its bound to be a bit messy

# %%
update = update_data.copy()
update.head(2)
# Out:
#                                                           channel  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  Entertainment
# http://mashable.com/2013/01/07/earth-size-plane...          World
#
#                                                                  date  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  Mon, 07 Jan 2013
# http://mashable.com/2013/01/07/earth-size-plane...  Mon, 07 Jan 2013
#
#                                                                                                 title  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  <title>This Astronaut Is Rooting for Notre Dam...
# http://mashable.com/2013/01/07/earth-size-plane...  <title>There Are 17 Billion Earth-Size Alien P...
#
#                                                                                              keywords
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  [<a href="/category/space/">Space</a>, <a href...
# http://mashable.com/2013/01/07/earth-size-plane...  [<a href="/category/alien-planets/">alien plan...

# %%
# Sperate the time stamp into weekday and date
update['weekday'] = update['date'].str.split(",", n = 1, expand = True)[0]
update['date'] = pd.to_datetime(update['date'].str.split(",", n = 1, expand = True)[1])

# Edit text of titles and keywords
def remove_text(column,text_list):
    update[column] = update[column].str.lower()
    for string in text_list:
        update[column] = update[column].str.replace(string,'')
        
remove = [r"\<.*?\>",'amp;','[',']']
remove_text('keywords',remove)
remove_text('title',remove)

update.head(2)
# Out:
#                                                           channel       date  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  Entertainment 2013-01-07
# http://mashable.com/2013/01/07/earth-size-plane...          World 2013-01-07
#
#                                                                                                 title  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...   this astronaut is rooting for notre dame tonight
# http://mashable.com/2013/01/07/earth-size-plane...  there are 17 billion earth-size alien planets ...
#
#                                                                                           keywords  \
# url
# http://mashable.com/2013/01/07/astronaut-notre-...  space, college football, entertainment, sports
# http://mashable.com/2013/01/07/earth-size-plane...              alien planets, earth, space, world
#
#                                                    weekday
# url
# http://mashable.com/2013/01/07/astronaut-notre-...     Mon
# http://mashable.com/2013/01/07/earth-size-plane...     Mon

# %% [markdown]
# ## Keywords
# Split the `keywords` columns into something useable

# %%
# Split the keywords into seperate entries
keywords_df = update.keywords.dropna().str.split(', ',expand=True).reset_index()
keywords_df = pd.melt(keywords_df,id_vars=['url'],value_name='keyword')
keywords_df = keywords_df.dropna().drop(columns='variable')

# Create a new data frame made up of keywords, shares, and url
keyword_shares = keywords_df.merge(raw.shares, how='left',on='url')
keyword_shares = keyword_shares[keyword_shares.url != ''].set_index('url')
keyword_shares.head()
# Out:
#                                                           keyword  shares
# url
# http://mashable.com/2013/01/07/astronaut-notre-...          space    1200
# http://mashable.com/2013/01/07/earth-size-plane...  alien planets    1600
# http://mashable.com/2013/01/07/apple-40-billion...          apple    1500
# http://mashable.com/2013/01/07/downton-abbey-tu...  downton abbey     761
# http://mashable.com/2013/01/07/att-u-verse-apps/             apps     505

# %%
# How many keywords are there?
len(keyword_shares['keyword'].unique())
# Out:
# 16724

# %%
# Drop keywords only used once
keyword_counts = keyword_shares.keyword.value_counts()
keyword_counts = keyword_counts[keyword_counts>1].index

keyword_shares = keyword_shares.reset_index().set_index('keyword').loc[keyword_counts]
keyword_shares = keyword_shares.reset_index().set_index('url')

# %%
# Get the min, avg, and max of each keyword
kw_min_max = keyword_shares.groupby('keyword').max().rename(columns={'shares':'max'})
kw_min_max['avg'] = keyword_shares.groupby('keyword').mean().astype('int')
kw_min_max['min'] = keyword_shares.groupby('keyword').min()

# %%
# Select the feautres of the best, worst, and middle keywords

kw_dict = {'url':[],
          'kw_min':[],'kw_min_min':[],'kw_min_avg':[],'kw_min_max':[],
          'kw_avg':[],'kw_avg_min':[],'kw_avg_avg':[],'kw_avg_max':[],
          'kw_max':[],'kw_max_min':[],'kw_max_avg':[],'kw_max_max':[]}

for url in keyword_shares.index.unique():
    article = keyword_shares.loc[url]
    if type(article) == pd.core.series.Series:
        key = article.loc['keyword']
        min_share = kw_min_max.loc[key]['min']
        avg_share = kw_min_max.loc[key]['avg']
        max_share = kw_min_max.loc[key]['max']
        
        kw_dict['url'].append(url)
        
        for col in ['kw_min','kw_avg','kw_max']:
            kw_dict[col].append(key)
            
        for col in ['min','avg','max']:
            kw_dict['kw_'+col+'_min'].append(min_share)
            kw_dict['kw_'+col+'_avg'].append(avg_share)
            kw_dict['kw_'+col+'_max'].append(max_share)
        
    if type(article) == pd.core.frame.DataFrame:
        keys = article['keyword'].values
        article_kw = kw_min_max.loc[keys].sort_values('avg').reset_index()
  
        kw_min = article_kw.iloc[0]
        kw_max = article_kw.iloc[-1]
        kw_avg = article_kw.iloc[int(len(article)/2)]
          
        kw_dict['url'].append(url)
    
        kw_dict['kw_min'].append(kw_min['keyword'])
        kw_dict['kw_min_min'].append(kw_min['min'])
        kw_dict['kw_min_avg'].append(kw_min['avg'])
        kw_dict['kw_min_max'].append(kw_min['max'])
        
        kw_dict['kw_avg'].append(kw_avg['keyword'])
        kw_dict['kw_avg_min'].append(kw_avg['min'])
        kw_dict['kw_avg_avg'].append(kw_avg['avg'])
        kw_dict['kw_avg_max'].append(kw_avg['max'])
        
        kw_dict['kw_max'].append(kw_max['keyword'])
        kw_dict['kw_max_min'].append(kw_max['min'])
        kw_dict['kw_max_avg'].append(kw_max['avg'])
        kw_dict['kw_max_max'].append(kw_max['max'])

kw_min_max_all = pd.DataFrame(kw_dict).set_index('url')
kw_min_max_all.head()
# Out:
#                                                            kw_min  kw_min_min  \
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/            world          22
# http://mashable.com/2013/02/28/pope-benedict-la...  pope francis          404
# http://mashable.com/2013/03/13/pope-francis-fac...  pope francis          404
# http://mashable.com/2013/03/27/biggest-cyberatt...          world          22
# http://mashable.com/2013/03/28/ddos-attacks-not...          world          22
#
#                                                     kw_min_avg  kw_min_max  \
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/          3223      310800
# http://mashable.com/2013/02/28/pope-benedict-la...        2963       23600
# http://mashable.com/2013/03/13/pope-francis-fac...        2963       23600
# http://mashable.com/2013/03/27/biggest-cyberatt...        3223      310800
# http://mashable.com/2013/03/28/ddos-attacks-not...        3223      310800
#
#                                                    kw_avg  kw_avg_min  \
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/    world          22
# http://mashable.com/2013/02/28/pope-benedict-la...  world          22
# http://mashable.com/2013/03/13/pope-francis-fac...  world          22
# http://mashable.com/2013/03/27/biggest-cyberatt...  world          22
# http://mashable.com/2013/03/28/ddos-attacks-not...  world          22
#
#                                                     kw_avg_avg  kw_avg_max  \
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/          3223      310800
# http://mashable.com/2013/02/28/pope-benedict-la...        3223      310800
# http://mashable.com/2013/03/13/pope-francis-fac...        3223      310800
# http://mashable.com/2013/03/27/biggest-cyberatt...        3223      310800
# http://mashable.com/2013/03/28/ddos-attacks-not...        3223      310800
#
#                                                    kw_max  kw_max_min  \
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/    world          22
# http://mashable.com/2013/02/28/pope-benedict-la...  world          22
# http://mashable.com/2013/03/13/pope-francis-fac...  world          22
# http://mashable.com/2013/03/27/biggest-cyberatt...  world          22
# http://mashable.com/2013/03/28/ddos-attacks-not...  world          22
#
#                                                     kw_max_avg  kw_max_max
# url
# http://mashable.com/2013/02/14/iceland-ban-porn/          3223      310800
# http://mashable.com/2013/02/28/pope-benedict-la...        3223      310800
# http://mashable.com/2013/03/13/pope-francis-fac...        3223      310800
# http://mashable.com/2013/03/27/biggest-cyberatt...        3223      310800
# http://mashable.com/2013/03/28/ddos-attacks-not...        3223      310800

# %% [markdown]
# # Join Dataframes
# Add these new keyword features to the dataset

# %%
update = update.merge(kw_min_max_all,how='right',right_index=True,left_index=True).drop(columns='keywords')

temp_data = raw.drop(columns=['kw_min_min','kw_min_avg','kw_min_max',
                          'kw_avg_min','kw_avg_avg','kw_avg_max',
                          'kw_max_min','kw_max_avg','kw_max_max'])

data = temp_data.reset_index().join(update, on='url',how='inner').set_index('url').dropna()

# %% [markdown]
# # Days of the Week
# Compare the old `weekday_is` column with the new `weekday` column

# %%
weekday_is = ['weekday_is_monday','weekday_is_tuesday','weekday_is_wednesday','weekday_is_thursday',
              'weekday_is_friday','weekday_is_saturday','weekday_is_sunday','is_weekend','timedelta']

weekday_is_dist = data[weekday_is[:-2]].sum()

plt.figure(figsize=(8,4),dpi=100)
plt.bar(x=weekday_is_dist.index.str.replace('weekday_is_',''),height=weekday_is_dist.values)
plt.title('weekday_is');

# %%
def break_down(column,sort='total articles',plot=True):
    counts = data[[column,'shares']].groupby(by=column).count().rename(columns={'shares':'total articles'})
    sums = data[[column,'shares']].groupby(by=column).sum().rename(columns={'shares':'sum shares'})
    group = counts.join(sums,on=column)
    
    # add the shares per article ratio
    group["shares per article ratio"] = group["sum shares"]/group["total articles"]

    # add percentages to make it easier to see
    group['percent of all shares'] = group['sum shares']/group['sum shares'].sum()*100
    group['percent of articles'] = group['total articles']/group['total articles'].sum()*100

    # sort
    group = group.sort_values('total articles',ascending=False)
    
    if plot==True:
        plt.figure(figsize=(8,4),dpi=100)
        plt.title(column)
        plt.bar(x=group.index,height=group['total articles'])

    return group

break_down('weekday')
# Out:
#          total articles  sum shares  shares per article ratio  \
# weekday
# Wed                7501    25017056               3335.162778
# Thu                7298    22993786               3150.696903
# Tue                7187    24285807               3379.129957
# Mon                6324    21947668               3470.535737
# Fri                5998    19789487               3299.347616
# Sat                2726    10806802               3964.344094
# Sun                2434     9043838               3715.627773
#
#          percent of all shares  percent of articles
# weekday
# Wed                  18.685558            19.005270
# Thu                  17.174352            18.490929
# Tue                  18.139379            18.209689
# Mon                  16.392993            16.023107
# Fri                  14.781020            15.197122
# Sat                   8.071738             6.906861
# Sun                   6.754958             6.167021

# %% [markdown]
# Seems like less articles are published on Saturday and Sunday so I combined both these entries as `weekend`

# %%
data['weekday'] = data['weekday'].replace(['Sat','Sun'],'Weekend')
break_down('weekday')
# Out:
#          total articles  sum shares  shares per article ratio  \
# weekday
# Wed                7501    25017056               3335.162778
# Thu                7298    22993786               3150.696903
# Tue                7187    24285807               3379.129957
# Mon                6324    21947668               3470.535737
# Fri                5998    19789487               3299.347616
# Weekend            5160    19850640               3847.023256
#
#          percent of all shares  percent of articles
# weekday
# Wed                  18.685558            19.005270
# Thu                  17.174352            18.490929
# Tue                  18.139379            18.209689
# Mon                  16.392993            16.023107
# Fri                  14.781020            15.197122
# Weekend              14.826696            13.073883

# %%
# Drop the weekday_is columns
data = data.drop(columns=weekday_is)

# %% [markdown]
# # Data Channels
# Compare the `data_channel_is` columns with the new `channel` column

# %%
data_channel_is = ['data_channel_is_lifestyle',' data_channel_is_entertainment','data_channel_is_bus',
                   'data_channel_is_socmed','data_channel_is_tech','data_channel_is_world']

data_channel_is_dist = data[data_channel_is].sum()

plt.figure(figsize=(8,4),dpi=100)
plt.bar(x=data_channel_is_dist.index.str.replace('data_channel_is_',''),height=data_channel_is_dist.values)
plt.title('data_channel_is');

# %%
break_down('channel')
# Out:
#                total articles  sum shares  shares per article ratio  \
# channel
# Entertainment           10775    35489784               3293.715452
# World                    7616    24084453               3162.349396
# Tech                     7260    25208532               3472.249587
# Business                 6180    21250001               3438.511489
# Culture                  5250    19215172               3660.032762
# Unlabeled                1182     3601668               3047.096447
# U.S.                      883     3673081               4159.774632
# Social Good               322     1361753               4229.046584
#
#                percent of all shares  percent of articles
# channel
# Entertainment              26.507773            27.300598
# World                      17.988985            19.296645
# Tech                       18.828574            18.394649
# Business                   15.871897            15.658255
# Culture                    14.352057            13.301915
# Unlabeled                   2.690132             2.994831
# U.S.                        2.743471             2.237255
# Social Good                 1.017111             0.815851

# %% [markdown]
# The most articles are from the `Entertainment` category, followed by `World` and `Tech`. Understandably the highest sum shares come from the same categories.
#
# Since `Social Good`, `US`, and the unlabeled data channels are so small, I just grouped them up into one category labeled `Other`

# %%
data['channel'] = data['channel'].replace(['Social Good','U.S.','Unlabeled'],'Other')
break_down('channel')
# Out:
#                total articles  sum shares  shares per article ratio  \
# channel
# Entertainment           10775    35489784               3293.715452
# World                    7616    24084453               3162.349396
# Tech                     7260    25208532               3472.249587
# Business                 6180    21250001               3438.511489
# Culture                  5250    19215172               3660.032762
# Other                    2387     8636502               3618.140762
#
#                percent of all shares  percent of articles
# channel
# Entertainment              26.507773            27.300598
# World                      17.988985            19.296645
# Tech                       18.828574            18.394649
# Business                   15.871897            15.658255
# Culture                    14.352057            13.301915
# Other                       6.450714             6.047938

# %%
# drop the data_channel_is columns
data = data.drop(columns=data_channel_is)

# %% [markdown]
# # Distribution of Shares
# Now that the weekdays and channels have been updated, lets look at the shares as a whole

# %%
plt.figure(figsize=(10,5),dpi=200)

plt.subplot(121)
plt.hist(data['shares'],bins=20);
plt.title('Distribution of Shares')

plt.subplot(122)
plt.hist(data['shares'],bins=20,range=(0,10000))
plt.title('Distribution of Shares - Zoomed In');

# %% [markdown]
# Seems like there's alot of outlires. Viral articles get a whole lot more shares than the typical article

# %% [markdown]
# # Save Data

# %% [markdown]
# Saved the data as `OnlineNewsPopularity_Cleaned.csv`.

# %%
data.head()
# Out:
#                                                     n_tokens_title  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...            12.0
# http://mashable.com/2013/01/07/ap-samsung-spons...             9.0
# http://mashable.com/2013/01/07/apple-40-billion...             9.0
# http://mashable.com/2013/01/07/astronaut-notre-...             9.0
# http://mashable.com/2013/01/07/att-u-verse-apps/              13.0
#
#                                                     n_tokens_content  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...             219.0
# http://mashable.com/2013/01/07/ap-samsung-spons...             255.0
# http://mashable.com/2013/01/07/apple-40-billion...             211.0
# http://mashable.com/2013/01/07/astronaut-notre-...             531.0
# http://mashable.com/2013/01/07/att-u-verse-apps/              1072.0
#
#                                                     n_unique_tokens  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...         0.663594
# http://mashable.com/2013/01/07/ap-samsung-spons...         0.604743
# http://mashable.com/2013/01/07/apple-40-billion...         0.575130
# http://mashable.com/2013/01/07/astronaut-notre-...         0.503788
# http://mashable.com/2013/01/07/att-u-verse-apps/           0.415646
#
#                                                     n_non_stop_words  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...               1.0
# http://mashable.com/2013/01/07/ap-samsung-spons...               1.0
# http://mashable.com/2013/01/07/apple-40-billion...               1.0
# http://mashable.com/2013/01/07/astronaut-notre-...               1.0
# http://mashable.com/2013/01/07/att-u-verse-apps/                 1.0
#
#                                                     n_non_stop_unique_tokens  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...                  0.815385
# http://mashable.com/2013/01/07/ap-samsung-spons...                  0.791946
# http://mashable.com/2013/01/07/apple-40-billion...                  0.663866
# http://mashable.com/2013/01/07/astronaut-notre-...                  0.665635
# http://mashable.com/2013/01/07/att-u-verse-apps/                    0.540890
#
#                                                     num_hrefs  num_self_hrefs  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...        4.0             2.0
# http://mashable.com/2013/01/07/ap-samsung-spons...        3.0             1.0
# http://mashable.com/2013/01/07/apple-40-billion...        3.0             1.0
# http://mashable.com/2013/01/07/astronaut-notre-...        9.0             0.0
# http://mashable.com/2013/01/07/att-u-verse-apps/         19.0            19.0
#
#                                                     num_imgs  num_videos  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...       1.0         0.0
# http://mashable.com/2013/01/07/ap-samsung-spons...       1.0         0.0
# http://mashable.com/2013/01/07/apple-40-billion...       1.0         0.0
# http://mashable.com/2013/01/07/astronaut-notre-...       1.0         0.0
# http://mashable.com/2013/01/07/att-u-verse-apps/        20.0         0.0
#
#                                                     average_token_length  ...  \
# url                                                                       ...
# http://mashable.com/2013/01/07/amazon-instant-v...              4.680365  ...
# http://mashable.com/2013/01/07/ap-samsung-spons...              4.913725  ...
# http://mashable.com/2013/01/07/apple-40-billion...              4.393365  ...
# http://mashable.com/2013/01/07/astronaut-notre-...              4.404896  ...
# http://mashable.com/2013/01/07/att-u-verse-apps/                4.682836  ...
#
#                                                     kw_min_avg  kw_min_max  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...        2722       83300
# http://mashable.com/2013/01/07/ap-samsung-spons...        2943       74100
# http://mashable.com/2013/01/07/apple-40-billion...        3249      298400
# http://mashable.com/2013/01/07/astronaut-notre-...        1342        3100
# http://mashable.com/2013/01/07/att-u-verse-apps/          2686       53100
#
#                                                                kw_avg  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...      entertainment
# http://mashable.com/2013/01/07/ap-samsung-spons...            twitter
# http://mashable.com/2013/01/07/apple-40-billion...           business
# http://mashable.com/2013/01/07/astronaut-notre-...             sports
# http://mashable.com/2013/01/07/att-u-verse-apps/    apps and software
#
#                                                     kw_avg_min  kw_avg_avg  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...           5        3267
# http://mashable.com/2013/01/07/ap-samsung-spons...          52        3349
# http://mashable.com/2013/01/07/apple-40-billion...          44        3431
# http://mashable.com/2013/01/07/astronaut-notre-...          43        3140
# http://mashable.com/2013/01/07/att-u-verse-apps/            47        3447
#
#                                                     kw_avg_max         kw_max  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...      652900          video
# http://mashable.com/2013/01/07/ap-samsung-spons...      145500       business
# http://mashable.com/2013/01/07/apple-40-billion...      690400           apps
# http://mashable.com/2013/01/07/astronaut-notre-...      200100  entertainment
# http://mashable.com/2013/01/07/att-u-verse-apps/        211600           apps
#
#                                                     kw_max_min  kw_max_avg  \
# url
# http://mashable.com/2013/01/07/amazon-instant-v...           5        3637
# http://mashable.com/2013/01/07/ap-samsung-spons...          44        3431
# http://mashable.com/2013/01/07/apple-40-billion...          47        3526
# http://mashable.com/2013/01/07/astronaut-notre-...           5        3267
# http://mashable.com/2013/01/07/att-u-verse-apps/            47        3526
#
#                                                     kw_max_max
# url
# http://mashable.com/2013/01/07/amazon-instant-v...      617900
# http://mashable.com/2013/01/07/ap-samsung-spons...      690400
# http://mashable.com/2013/01/07/apple-40-billion...      143100
# http://mashable.com/2013/01/07/astronaut-notre-...      652900
# http://mashable.com/2013/01/07/att-u-verse-apps/        143100
#
# [5 rows x 52 columns]

# %%
data.to_csv('../Data/Clean - EDA.csv')
